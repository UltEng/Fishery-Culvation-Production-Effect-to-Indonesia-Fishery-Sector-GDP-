# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
# !pip install squarify
import squarify as sq

import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as pyoff
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
plt.style.use('seaborn')
sns.set(rc={'figure.figsize':(15, 8)})

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Produksi Perikanan

# %%
prod = pd.read_excel('drive/MyDrive/Capstone Tetris/Produksi.xlsx')

# %%
prod.head()
# Out:
#   Jenis Usaha Provinsi Jenis Ikan  Tahun  Volume Produksi  Nilai Produksi
# 0    BUDIDAYA     ACEH    BANDENG   2011         16746.80       251202000
# 1    BUDIDAYA     ACEH    BANDENG   2012         18492.30       295876800
# 2    BUDIDAYA     ACEH    BANDENG   2013         20530.00       315768921
# 3    BUDIDAYA     ACEH    BANDENG   2014         23914.10       373190273
# 4    BUDIDAYA     ACEH    BANDENG   2015         24930.75       393447645

# %% [markdown]
# # Luas Lahan Budidaya

# %%
df_luas_raw =pd.read_excel('drive/MyDrive/Capstone Tetris/Luas Lahan.xlsx')

# %%
df_luas_raw.head()
# Out:
#                      Provinsi       2011.0       2012.0       2013.0  \
# 0                        ACEH  550748880.0  552473814.0  555653500.0
# 1                        BALI   26669000.0   22636000.0   27598000.0
# 2                      BANTEN  111622060.0  162822096.0  167244030.0
# 3                    BENGKULU   96755672.0   77108300.0   87062200.0
# 4  DAERAH ISTIMEWA YOGYAKARTA   10415813.0    9735177.0   11383432.0
#
#         2014.0       2015.0       2016.0       2017.0       2018.0  \
# 0  556477848.0  521092673.0  602956400.0  602956400.0  691389303.0
# 1   20831000.0   19843000.0   24267000.0   24267000.0    8150145.0
# 2  159605860.0  160115900.0  158864016.0  158864016.0  158557360.0
# 3   89538100.0  115162199.0  104011400.0  104011400.0  170239534.0
# 4   58543300.0   13583400.0   14671200.0   14671200.0   13635085.0
#
#          2019.0        2020.0
# 0  1.036911e+09  1.447134e+09
# 1  1.410324e+07  2.257368e+07
# 2  2.482529e+08  2.043835e+08
# ...

# %%
df_luas_raw.shape
# Out:
# (34, 11)

# %%
luas = df_luas_raw.transpose().iloc[1].to_numpy()
i = 2
while i < df_luas_raw.shape[1]:
    data= df_luas_raw.transpose().iloc[i].to_numpy()
    luas = np.concatenate((luas, data))
    i = i + 1
print(luas)
print(len(luas))
# Out:
# [550748880.0 26669000.0 111622060.0 96755672.0 10415813.0 6391800.0
#  57230971.0 32328699.0 1293307500.0 482545100.0 1060007510.0 241655889.0
#  155240868.0 60253800.0 1613047079.0 0.0 5784800.0 53778380.0 546976610.0
#  467591700.0 17560300.0 279817064.0 79120000.0 19520700.0 4091000.0
#  63669640.0 218297350.0 1605669015.0 301711494.0 486150000.0 117305532.0
#  130930507.0 614431153.0 205442000.0 552473814.0 22636000.0 162822096.0
#  77108300.0 9735177.0 5329522.0 54833570.0 29861313.0 1291694991.0
#  517823100.0 1057150775.0 250297080.0 158262206.0 67272800.0 1780961583.0
#  0.0 5144500.0 69188581.0 383340230.0 504296460.0 27877100.0 310793935.0
#  85140000.0 24375004.0 17535284.0 31114030.0 226788064.0 1591648236.0
#  303648718.0 482945400.0 143684332.0 153683854.0 646684465.0 209619800.0
#  555653500.0 27598000.0 167244030.0 87062200.0 11383432.0 4118684.0
#  58897111.0 28221500.0 1301096077.0 400064099.0 2301956738.0 269885246.0
# ...

# %%
from itertools import repeat
year = []
i = 2011
while i < 2021:
    year.extend(repeat(i,df_luas_raw.shape[0]))
    i = i + 1
print(year)
print(len(year))
# Out:
# [2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2
# ...

# %%
provinsi = df_luas_raw.transpose().iloc[0].to_numpy()
i = 2
while i < df_luas_raw.shape[1]:
    data = df_luas_raw.transpose().iloc[0].to_numpy()
    provinsi = np.concatenate((provinsi, data))
    i = i + 1
print(provinsi)
print(len(provinsi))
# Out:
# ['ACEH' 'BALI' 'BANTEN' 'BENGKULU' 'DAERAH ISTIMEWA YOGYAKARTA'
#  'DKI JAKARTA' 'GORONTALO' 'JAMBI' 'JAWA BARAT' 'JAWA TENGAH' 'JAWA TIMUR'
#  'KALIMANTAN BARAT' 'KALIMANTAN SELATAN' 'KALIMANTAN TENGAH'
#  'KALIMANTAN TIMUR' 'KALIMANTAN UTARA' 'KEPULAUAN BANGKA BELITUNG'
#  'KEPULAUAN RIAU' 'LAMPUNG' 'MALUKU' 'MALUKU UTARA' 'NUSA TENGGARA BARAT'
#  'NUSA TENGGARA TIMUR' 'PAPUA' 'PAPUA BARAT' 'RIAU' 'SULAWESI BARAT'
#  'SULAWESI SELATAN' 'SULAWESI TENGAH' 'SULAWESI TENGGARA' 'SULAWESI UTARA'
#  'SUMATERA BARAT' 'SUMATERA SELATAN' 'SUMATERA UTARA' 'ACEH' 'BALI'
#  'BANTEN' 'BENGKULU' 'DAERAH ISTIMEWA YOGYAKARTA' 'DKI JAKARTA'
#  'GORONTALO' 'JAMBI' 'JAWA BARAT' 'JAWA TENGAH' 'JAWA TIMUR'
#  'KALIMANTAN BARAT' 'KALIMANTAN SELATAN' 'KALIMANTAN TENGAH'
#  'KALIMANTAN TIMUR' 'KALIMANTAN UTARA' 'KEPULAUAN BANGKA BELITUNG'
#  'KEPULAUAN RIAU' 'LAMPUNG' 'MALUKU' 'MALUKU UTARA' 'NUSA TENGGARA BARAT'
#  'NUSA TENGGARA TIMUR' 'PAPUA' 'PAPUA BARAT' 'RIAU' 'SULAWESI BARAT'
# ...

# %%
dict1 = {'provinsi' : provinsi, 'tahun' : year, 'luas lahan' : luas }
luas = pd.DataFrame(dict1, columns=['provinsi','tahun','luas lahan'])
luas = luas.drop(luas.index[0])
luas.head()
# Out:
#                      provinsi  tahun   luas lahan
# 1                        BALI   2011   26669000.0
# 2                      BANTEN   2011  111622060.0
# 3                    BENGKULU   2011   96755672.0
# 4  DAERAH ISTIMEWA YOGYAKARTA   2011   10415813.0
# 5                 DKI JAKARTA   2011    6391800.0

# %% [markdown]
# # Rumah Tangga Perikanan

# %%
df_rtpb_raw =pd.read_excel('drive/MyDrive/Capstone Tetris/RTP Budidaya.xlsx')
df_rtpl_raw =pd.read_excel('drive/MyDrive/Capstone Tetris/RTP Laut.xlsx')
df_rtpp_raw =pd.read_excel('drive/MyDrive/Capstone Tetris/RTP PUD.xlsx')

# %%
df_rtpb_raw.head()
# Out:
#                      Provinsi  2011   2012   2013   2014   2015   2016   2017  \
# 0                        ACEH     0  46641  47340  47649  47274  48579  48579
# 1                        BALI     0  14107  12527  10879   9744  10441  10441
# 2                      BANTEN     0  25187  24843  25169  25550  20949  20949
# 3                    BENGKULU     0  12942  15249  17458  20829  20622  20622
# 4  DAERAH ISTIMEWA YOGYAKARTA     0  64101  67497  66976  69806  59903  59903
#
#     2018   2019   2020
# 0  48680  35855  48458
# 1   8545  10320  10617
# 2  26646  20741  20867
# 3  32466  28650  15371
# 4  66763  61200  62781

# %%
df_rtpb_raw.shape
# Out:
# (34, 11)

# %%
jum = []
i = 1
j = 1
k = 1
while i < df_rtpb_raw.shape[1]:
    data= df_rtpb_raw.transpose().iloc[i].to_numpy()
    jum = np.concatenate((jum, data))
    i = i + 1
while j < df_rtpb_raw.shape[1]:
    data= df_rtpl_raw.transpose().iloc[j].to_numpy()
    jum = np.concatenate((jum, data))
    j = j + 1
while k < df_rtpb_raw.shape[1]:
    data= df_rtpp_raw.transpose().iloc[k].to_numpy()
    jum = np.concatenate((jum, data))
    k = k + 1
print(jum)
print(len(jum))
# Out:
# [0 0 0 ... 13366 43800 10555]
# 1020

# %%
tahun = []
i = 2011
j = 2011
k = 2011
while i < 2021:
    tahun.extend(repeat(i,df_rtpb_raw.shape[0]))
    i = i + 1
while j < 2021:
    tahun.extend(repeat(j,df_rtpb_raw.shape[0]))
    j = j + 1
while k < 2021:
    tahun.extend(repeat(k,df_rtpb_raw.shape[0]))
    k = k + 1
print(tahun)
print(len(tahun))
# Out:
# [2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2
# ...

# %%
prov = []
i = 1
j = 1
k = 1
while i < df_rtpb_raw.shape[1]:
    data = df_rtpb_raw.transpose().iloc[0].to_numpy()
    prov = np.concatenate((prov, data))
    i = i + 1
while j < df_rtpb_raw.shape[1]:
    data = df_rtpb_raw.transpose().iloc[0].to_numpy()
    prov = np.concatenate((prov, data))
    j = j + 1
while k < df_rtpb_raw.shape[1]:
    data = df_rtpb_raw.transpose().iloc[0].to_numpy()
    prov = np.concatenate((prov, data))
    k = k + 1
print(prov)
print(len(prov))
# Out:
# ['ACEH' 'BALI' 'BANTEN' ... 'SUMATERA BARAT' 'SUMATERA SELATAN'
#  'SUMATERA UTARA']
# 1020

# %%
jenis_rtp = []
jenis_rtp.extend(repeat('Budidaya', 340))
jenis_rtp.extend(repeat('Laut', 340))
jenis_rtp.extend(repeat('PUD', 340))
print(jenis_rtp)
print(len(jenis_rtp))
# Out:
# ['Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', 'Budidaya', '
# ...

# %%
dict2 = {'provinsi' : prov, 'tahun' : tahun,'jenis' : jenis_rtp, 'jumlah RTP' : jum }
rtp = pd.DataFrame(dict2, columns=['provinsi','tahun','jenis', 'jumlah RTP'])
rtp = rtp.drop(rtp.index[0])
rtp.head()
# Out:
#                      provinsi  tahun     jenis jumlah RTP
# 1                        BALI   2011  Budidaya          0
# 2                      BANTEN   2011  Budidaya          0
# 3                    BENGKULU   2011  Budidaya          0
# 4  DAERAH ISTIMEWA YOGYAKARTA   2011  Budidaya          0
# 5                 DKI JAKARTA   2011  Budidaya          0

# %% [markdown]
# # Angka Konsumsi Ikan

# %%
aki_raw = pd.read_excel('drive/MyDrive/Capstone Tetris/Angka Konsumsi Ikan.xlsx')

# %%
aki_raw.head()
# Out:
#                      Provinsi  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0  \
# 0                        ACEH   40.96   41.69   43.34   45.83   46.85   49.80
# 1                        BALI   24.40   24.75   28.66   31.47   33.02   37.43
# 2                      BANTEN   24.89   28.36   28.06   30.65   32.45   35.77
# 3                    BENGKULU   25.52   26.80   30.70   32.18   34.39   37.29
# 4  DAERAH ISTIMEWA YOGYAKARTA   13.60   14.55   21.71   21.74   24.68   23.73
#
#    2017.0  2018.0  2019.0  2020.0
# 0   49.37   57.19   63.62   65.53
# 1   37.56   38.83   41.45   44.74
# 2   36.41   37.41   42.94   41.29
# 3   53.36   54.36   40.79   45.74
# 4   28.32   28.71   33.35   34.26

# %%
jumlah_aki = aki_raw.transpose().iloc[1].to_numpy()
i = 2
while i < aki_raw.shape[1]:
    data= aki_raw.transpose().iloc[i].to_numpy()
    jumlah_aki = np.concatenate((jumlah_aki, data))
    i = i + 1
print(jumlah_aki)
print(len(jumlah_aki))
# Out:
# [40.96 24.4 24.89 25.52 13.6 25.14 40.91 31.55 20.79 15.51 21.41 31.53
#  42.69 44.36 37.99 0.0 38.82 46.86 22.31 48.87 45.19 26.09 21.21 33.62
#  41.83 37.85 42.76 42.08 38.35 46.09 41.71 29.53 30.42 35.54 41.69 24.75
#  28.36 26.8 14.55 31.31 43.73 31.94 22.67 17.71 23.35 32.88 44.63 44.97
#  39.18 0.0 45.75 46.96 24.41 49.86 46.37 28.67 23.16 34.58 42.73 38.04
#  44.76 41.77 40.25 47.51 43.08 31.18 35.31 35.59 43.34 28.66 28.06 30.7
#  21.71 31.32 46.83 32.76 22.51 18.19 25.09 34.75 45.35 45.89 40.75 0.0
#  45.87 49.26 25.11 53.95 48.63 30.5 28.15 35.43 47.13 40.02 45.37 44.88
#  40.31 49.01 45.67 33.4 37.89 38.94 45.83 31.47 30.65 32.18 21.74 32.55
#  47.74 34.0 24.48 20.92 27.89 36.9 46.5 46.19 41.81 0.0 47.04 49.92 25.97
#  54.12 48.88 31.15 30.11 38.59 49.51 41.74 46.16 45.4 45.07 50.77 47.83
#  34.16 38.99 40.14 46.85 33.02 32.45 34.39 24.68 36.75 50.56 34.75 26.27
#  22.37 29.42 38.63 48.4 48.87 43.12 41.83 49.26 52.58 28.66 55.35 50.75
# ...

# %%
dict3 = {'Provinsi' : provinsi, 'Tahun' : year, 'Jumlah AKI' : jumlah_aki }
aki = pd.DataFrame(dict3, columns=['Provinsi','Tahun','Jumlah AKI'])
aki = aki.drop(aki.index[0])
aki.head()
# Out:
#                      Provinsi  Tahun Jumlah AKI
# 1                        BALI   2011       24.4
# 2                      BANTEN   2011      24.89
# 3                    BENGKULU   2011      25.52
# 4  DAERAH ISTIMEWA YOGYAKARTA   2011       13.6
# 5                 DKI JAKARTA   2011      25.14

# %% [markdown]
# # impor Perikanan Indonesia

# %%
imp = pd.read_excel('drive/MyDrive/Capstone Tetris/Impor.xlsx')

# %%
imp.rename({'Nilai USD':'Nilai USD Impor'}, axis =1, inplace =True)
imp.head()
# Out:
#    Tahun  Volume Impor  Nilai USD Impor
# 0   2011     301897627        400534274
# 1   2012     270708401        389757011
# 2   2013     241274114        365215784
# 3   2014     220541708        331615009
# 4   2015     223021670        383734272

# %% [markdown]
# # Ekspor Perikanan Indonesia

# %%
eks = pd.read_excel('drive/MyDrive/Capstone Tetris/Ekspor.xlsx')

# %%
eks.rename({'Volume Impor':'Volume Ekspor','Nilai USD':'Nilai USD Ekspor'}, axis =1, inplace =True)
eks.head()
# Out:
#    Tahun  Volume Ekspor  Nilai USD Ekspor
# 0   2011     1365000000        3520000000
# 1   2012     1240088507        3871340953
# 2   2013     1240088507        4161354002
# 3   2014     1255418264        4641535680
# 4   2015     1273226732        3943691603

# %% [markdown]
# # Produk Domestik Bruto

# %%
pdb_raw = pd.read_excel('drive/MyDrive/Capstone Tetris/PDB.xlsx')

# %%
pdb_raw.head()
# Out:
#    Tahun  Triwulan    Nilai      Satuan
# 0   2011         1  36017.5  Rp. Miliar
# 1   2011         2  38319.5  Rp. Miliar
# 2   2011         3  40154.9  Rp. Miliar
# 3   2011         4  40053.3  Rp. Miliar
# 4   2012         1  39195.1  Rp. Miliar

# %%
pdb_raw['PDB'] = pdb_raw['Nilai'] * 1000000000
pdb_raw.head()
# Out:
#    Tahun  Triwulan    Nilai      Satuan           PDB
# 0   2011         1  36017.5  Rp. Miliar  3.601750e+13
# 1   2011         2  38319.5  Rp. Miliar  3.831950e+13
# 2   2011         3  40154.9  Rp. Miliar  4.015490e+13
# 3   2011         4  40053.3  Rp. Miliar  4.005330e+13
# 4   2012         1  39195.1  Rp. Miliar  3.919510e+13

# %%
pdb_group = pdb_raw.groupby('Tahun').sum()['PDB']
pdb_group.to_frame()
pdb_group = pdb_group.reset_index(level=0)
pdb_group.head()
# Out:
#    Tahun           PDB
# 0   2011  1.545452e+14
# 1   2012  1.642643e+14
# 2   2013  1.761493e+14
# 3   2014  1.890897e+14
# 4   2015  2.040168e+14

# %% [markdown]
# # Exploratory Data Anaylsis

# %% [markdown]
# ## Produksi Perikanan

# %%
jum_group = prod.groupby(['Jenis Usaha', 'Tahun']).sum()['Volume Produksi']
jum_group.to_frame()
jum_group = jum_group.reset_index(level= ['Jenis Usaha', 'Tahun'])
jum_group.head()
# Out:
#   Jenis Usaha  Tahun  Volume Produksi
# 0    BUDIDAYA   2011       7928962.11
# 1    BUDIDAYA   2012       9675490.61
# 2    BUDIDAYA   2013      13300905.82
# 3    BUDIDAYA   2014      14359129.52
# 4    BUDIDAYA   2015      15634093.05

# %%
prod_group = prod.groupby(['Jenis Usaha', 'Tahun']).sum()['Nilai Produksi']
prod_group.to_frame()
prod_group = prod_group.reset_index(level= ['Jenis Usaha', 'Tahun'])
prod_group.head()
# Out:
#   Jenis Usaha  Tahun  Nilai Produksi
# 0    BUDIDAYA   2011     66549923289
# 1    BUDIDAYA   2012     75922740419
# 2    BUDIDAYA   2013    111758806179
# 3    BUDIDAYA   2014    127695038337
# 4    BUDIDAYA   2015    121577620149

# %%
fig= px.line(jum_group, y = 'Volume Produksi', 
             labels = { 'Volume Produksi': 'Volume'}, 
              x = 'Tahun', color = 'Jenis Usaha',
             title = "Volume Produksi Tahunan Berdasarkan Jenis Usaha")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.line(prod_group, y = 'Nilai Produksi', 
             labels = { 'Nilai Produksi': 'Nilai'}, 
              x = 'Tahun', color = 'Jenis Usaha',
             title = "Nilai Produksi Tahunan Berdasarkan Jenis Usaha")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Luas Lahan

# %%
luas_group = luas.groupby(['tahun', 'provinsi']).sum()['luas lahan']
luas_group.to_frame()
luas_group = luas_group.reset_index(level=['tahun', 'provinsi'])
luas_group.head()
# Out:
#    tahun                    provinsi   luas lahan
# 0   2011                        BALI   26669000.0
# 1   2011                      BANTEN  111622060.0
# 2   2011                    BENGKULU   96755672.0
# 3   2011  DAERAH ISTIMEWA YOGYAKARTA   10415813.0
# 4   2011                 DKI JAKARTA    6391800.0

# %%
fig= px.line(luas_group, y = 'luas lahan', 
             labels = { 'luas lahan': 'Luas'}, 
              x = 'tahun', color = 'provinsi',
             title = "Luas Lahan Budidaya Tahunan Berdasarkan Provinsi")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Rumah Tangga Perikanan

# %%
rtp_group = rtp.groupby(['tahun', 'jenis']).sum()['jumlah RTP']
rtp_group.to_frame()
rtp_group = rtp_group.reset_index(level=['tahun', 'jenis'])
rtp_group.head()
# Out:
#    tahun     jenis  jumlah RTP
# 0   2011  Budidaya           0
# 1   2011      Laut      595200
# 2   2011       PUD      324928
# 3   2012  Budidaya     1670447
# 4   2012      Laut      627416

# %%
fig= px.line(rtp_group, y = 'jumlah RTP', 
             labels = { 'jumlah RTP': 'Jumlah'}, 
              x = 'tahun', color = 'jenis',
             title = "Jumlah RTP Tahunan Berdasarkan Jenis Usaha")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Angka Konsumsi Ikan

# %%
aki_group = aki.groupby(['Tahun', 'Provinsi']).sum()['Jumlah AKI']
aki_group.to_frame()
aki_group = aki_group.reset_index(level=['Tahun', 'Provinsi'])
aki_group.head()
# Out:
#    Tahun                    Provinsi  Jumlah AKI
# 0   2011                        BALI       24.40
# 1   2011                      BANTEN       24.89
# 2   2011                    BENGKULU       25.52
# 3   2011  DAERAH ISTIMEWA YOGYAKARTA       13.60
# 4   2011                 DKI JAKARTA       25.14

# %%
fig= px.line(aki_group, y = 'Jumlah AKI', 
             labels = { 'Jumlah AKI': 'Jumlah'}, 
              x = 'Tahun', color = 'Provinsi',
             title = "Jumlah Angka Konsumsi Ikan Tahunan Berdasarkan Provinsi")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Impor Perikanan

# %%
fig= px.line(imp, y = 'Volume Impor', 
             labels = { 'Volume Impor': 'Volume'}, 
              x = 'Tahun',
             title = "Volume Impor Tahunan")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.line(imp, y = 'Nilai USD Impor', 
             labels = { 'Nilai USD Impor': 'Nilai USD'}, 
              x = 'Tahun',
             title = "Nilai USD Impor Tahunan")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Ekspor Perikanan

# %%
fig= px.line(eks, y = 'Volume Ekspor', 
             labels = { 'Volume Ekspor': 'Volume'}, 
              x = 'Tahun',
             title = "Volume Ekspor Tahunan")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.line(eks, y = 'Nilai USD Ekspor', 
             labels = { 'Nilai USD Ekspor': 'Nilai USD'}, 
              x = 'Tahun',
             title = "Nilai USD Ekspor Tahunan")
fig.layout.plot_bgcolor = "light grey"
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Korelasi Variabel

# %%
prod_corr = prod_group[prod_group['Jenis Usaha'] == 'BUDIDAYA']
prod_corr.drop('Jenis Usaha', axis=1, inplace=True)
prod_corr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Tahun  Nilai Produksi
# 0   2011     66549923289
# 1   2012     75922740419
# 2   2013    111758806179
# 3   2014    127695038337
# 4   2015    121577620149

# %%
jum_corr = jum_group[jum_group['Jenis Usaha'] == 'BUDIDAYA']
jum_corr.drop('Jenis Usaha', axis=1, inplace=True)
jum_corr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Tahun  Volume Produksi
# 0   2011       7928962.11
# 1   2012       9675490.61
# 2   2013      13300905.82
# 3   2014      14359129.52
# 4   2015      15634093.05

# %%
luas_corr = luas.groupby(['tahun']).sum()['luas lahan']
luas_corr.to_frame()
luas_corr = luas_corr.reset_index(level=['tahun'])
luas_corr = luas_corr.rename({'tahun':'Tahun', 'luas lahan':'Luas Lahan'}, axis =1)
luas_corr.head()
# Out:
#    Tahun    Luas Lahan
# 0   2011  1.046532e+10
# 1   2012  1.125577e+10
# 2   2013  1.278437e+10
# 3   2014  1.253748e+10
# 4   2015  1.321844e+10

# %%
rtp_corr = rtp_group[rtp_group['jenis'] == 'Budidaya']
rtp_corr.drop('jenis', axis=1, inplace=True)
rtp_corr = rtp_corr.rename({'tahun':'Tahun','jumlah RTP':'Jumlah RTP'}, axis =1)
rtp_corr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Tahun  Jumlah RTP
# 0    2011           0
# 3    2012     1670447
# 6    2013     1667428
# 9    2014     1649171
# 12   2015     1624504

# %%
aki_corr = aki.groupby(['Tahun']).sum()['Jumlah AKI']
aki_corr.to_frame()
aki_corr = aki_corr.reset_index(level=0)
aki_corr.head()
# Out:
#    Tahun  Jumlah AKI
# 0   2011     1069.42
# 1   2012     1168.50
# 2   2013     1235.43
# 3   2014     1286.40
# 4   2015     1397.58

# %%
corr = prod_corr.merge(jum_corr, on='Tahun').merge(luas_corr, on='Tahun').merge(rtp_corr, on='Tahun').merge(aki_corr, on='Tahun').merge(imp, on= 'Tahun').merge(eks, on= 'Tahun')
corr.head()
# Out:
#    Tahun  Nilai Produksi  Volume Produksi    Luas Lahan  Jumlah RTP  \
# 0   2011     66549923289       7928962.11  1.046532e+10           0
# 1   2012     75922740419       9675490.61  1.125577e+10     1670447
# 2   2013    111758806179      13300905.82  1.278437e+10     1667428
# 3   2014    127695038337      14359129.52  1.253748e+10     1649171
# 4   2015    121577620149      15634093.05  1.321844e+10     1624504
#
#    Jumlah AKI  Volume Impor  Nilai USD Impor  Volume Ekspor  Nilai USD Ekspor
# 0     1069.42     301897627        400534274     1365000000        3520000000
# 1     1168.50     270708401        389757011     1240088507        3871340953
# 2     1235.43     241274114        365215784     1240088507        4161354002
# 3     1286.40     220541708        331615009     1255418264        4641535680
# 4     1397.58     223021670        383734272     1273226732        3943691603

# %%
import plotly.figure_factory as ff
df_corr = corr[['Nilai Produksi', 'Volume Produksi', 'Luas Lahan', 'Jumlah RTP', 'Jumlah AKI',
                'Volume Impor', 'Nilai USD Impor','Volume Ekspor', 'Nilai USD Ekspor' ]].corr()
x = list(df_corr.columns)
y = list(df_corr.index)
z = np.array(df_corr)

fig = px.imshow(z, x=x, y=y, color_continuous_scale='Viridis', aspect="auto")
fig.update_traces(text=np.around(z, decimals=2), texttemplate="%{text}")
fig.update_xaxes(side="top")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
corr1 = prod_corr.merge(pdb_group, on='Tahun')
corr1.head()
# Out:
#    Tahun  Nilai Produksi           PDB
# 0   2011     66549923289  1.545452e+14
# 1   2012     75922740419  1.642643e+14
# 2   2013    111758806179  1.761493e+14
# 3   2014    127695038337  1.890897e+14
# 4   2015    121577620149  2.040168e+14

# %%
fig = px.scatter(corr1, x="Nilai Produksi", y="PDB")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from scipy.stats import pearsonr

corr, _ = pearsonr(corr1["Nilai Produksi"], corr1["PDB"])
print('Pearsons correlation: %.3f' % corr)
if corr == 0:
  print('Tidak ada hubungan sama sekali')
elif corr > 0 and corr < 0.2:
  print('Hubungan sangat lemah')
elif corr >= 0.2 and corr < 0.4:
  print('Hubungan lemah')
elif corr >= 0.4 and corr < 0.6:
  print('Hubungan cukup kuat')
elif corr >= 0.6 and corr < 0.8:
  print('Hubungan kuat')
elif corr >= 0.8 and corr < 1:
  print('Hubungan sangat kuat')
elif corr == 1:
  print('Hubungan sempurna')
# Out:
# Pearsons correlation: 0.951
# Hubungan sangat kuat

# %%
luas.to_csv('drive/MyDrive/Capstone Tetris/luas_lahan.csv')

# %%
rtp.to_csv('drive/MyDrive/Capstone Tetris/rtp.csv')

# %%
prod.to_csv('drive/MyDrive/Capstone Tetris/prod.csv')

# %%
pdb_group.to_csv('drive/MyDrive/Capstone Tetris/pdb.csv')

# %%
aki.to_csv('drive/MyDrive/Capstone Tetris/aki.csv')

# %%
imp.to_csv('drive/MyDrive/Capstone Tetris/imp.csv')

# %%
eks.to_csv('drive/MyDrive/Capstone Tetris/eks.csv')
